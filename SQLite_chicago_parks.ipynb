# %%
# data science
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# API
import requests
import json

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, text, inspect, func

import sqlite3
import pandas as pd

# %%
# Read data from CSV into a DataFrame
df = pd.read_csv('Resources/chi_movies_in_the_park_2014_2019.csv')

# %%
df.head()
# Out:
#    title                         park                  date           phone  \
# 0  @home        Austin Town Hall Park  2014-05-30T01:30:00Z  (773) 287-7658
# 1  @home  Berger Park Cultural Center  2014-06-04T01:30:00Z  (773) 761-0376
# 2  @home              Lake Shore Park  2014-06-06T01:30:00Z  (312) 742-7891
# 3  @home                  Loyola Park  2014-05-31T01:30:00Z  (773) 262-8605
# 4  @home                  Palmer Park  2014-06-07T01:30:00Z  (312) 747-6577
#
#   rating  cc  location.latitude  location.longitude  \
# 0     NR  No          41.888058          -87.765785
# 1     NR  No          41.994759          -87.655540
# 2     NR  No          41.897491          -87.619926
# 3     NR  No          42.010414          -87.661179
# 4     NR  No          41.692631          -87.618195
#
#                              location.human_address2  datayear  ... state  \
# 0  {"address": "5610 W Lake St Chicago, IL 60644"...      2014  ...    IL
# ...

# %%
engine = create_engine('sqlite:///chi_movies_in_the_park_2014_2019.csv')

# %%
df.to_sql('Chicago_Park_Movies', engine, index=False, if_exists='replace')
# Out:
# 1408

# %%
# INSPECT to confirm existence

# Create the inspector and connect it to the engine
inspector_gadget = inspect(engine)

# Collect the names of tables within the database
tables = inspector_gadget.get_table_names()

# print metadata for each table
for table in tables:
    print(table)
    print("-----------")
    
    # get columns
    columns = inspector_gadget.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# Chicago_Park_Movies
# -----------
# title TEXT
# park TEXT
# date TEXT
# phone TEXT
# rating TEXT
# cc TEXT
# location.latitude FLOAT
# location.longitude FLOAT
# location.human_address2 TEXT
# datayear BIGINT
# day TEXT
# park_address TEXT
# address TEXT
# city TEXT
# state TEXT
# zip FLOAT
# community TEXT
# geocode_address TEXT
# lat FLOAT
# long FLOAT
# osm_type TEXT
# display_name TEXT
# class TEXT
# type TEXT

# %%
# close the engine
engine.dispose()
